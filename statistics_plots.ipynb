# %%
# %matplotlib inline
# plt.rcParams['savefig.dpi'] = 72
# plt.rcParams['figure.dpi'] = 72
# plt.rcParams['axes.labelsize'] = 12
# plt.rcParams['legend.fontsize'] = 12 
# plt.rcParams['font.family'] = 'serif'
# # plt.rcParams['figure.figsize'] = 5.2, 3.2   # 0.8
# # plt.rcParams['figure.figsize'] = 3.9, 2.4   # 0.6
# # plt.rcParams['figure.figsize'] = 2.9, 1.8   # 0.45
# plt.rcParams['figure.figsize'] = 4.5, 2.8   # 0.7

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.unicode'] = True
plt.rcParams['font.serif'] = ['Computer Modern Roman']  
plt.rcParams['figure.dpi'] = 72
plt.rcParams['xtick.labelsize'] = 12  
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12 
plt.rcParams['axes.linewidth'] = 0.5 
# plt.rcParams['figure.figsize'] = 5.2, 3.2   # 0.8
plt.rcParams['figure.figsize'] = 4.009962640099626, 2.4782932051988316   # 0.6

# plt.rcParams['text.latex.preamble'] = r'\usepackage[utf8]{inputenc}'
# 
# plt.rcParams['text.latex.preamble'] = r'\usepackage[russian]{babel}'
# \usepackage{mathrsfs}'''
plt.rcParams['text.latex.preamble'] = r'\usepackage[russian]{babel},\usepackage{mathrsfs},\usepackage{amsmath}'

# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)

# %%
x = linspace(-3.5, 6, 1000)
y0 = [norm.pdf(i, 0, 1) for i in x]
y1 = [norm.pdf(i, 2.5, 1) for i in x]

# %%
# plt.fill_between(x, y0, color = '#8E3CFC', where = (x > -4) & (x < -2))
# plt.fill_between(x, y0, color = '#8E3CFC', where = (x > 2) & (x < 4))
# plt.fill_between(x, y1, color = '#FFCA2A', where = (x > -4) & (x < 2))
# plt.plot(x, y0, color='#5100BC', label=r'$\mathrm{pdf}_t$ при верной $H_0$')
# plt.plot(x, y1, color='#d5a000', label=r'$\mathrm{pdf}_t$ при верной $H_1$')
plt.fill_between(x, y0, color='blue', alpha=0.2, where = (x > -4) & (x < -2))
plt.fill_between(x, y0, color='blue', alpha=0.2, where = (x > 2) & (x < 4))
plt.fill_between(x, y1, color='green', alpha=0.2, where = (x > -4) & (x < 2))
plt.plot(x, y0, label=r'$\mathrm{pdf}_t$ при верной $H_0$')
plt.plot(x, y1, label=r'$\mathrm{pdf}_t$ при верной $H_1$')
plt.plot([], [], color='blue', alpha=0.2, linewidth=10, label=r'$\alpha_{\mathrm{I}}$')
plt.plot([], [], color='green', alpha=0.2, linewidth=10, label=r'$\alpha_{\mathrm{II}} = \mathsf{P}_{H_1}(t \in \mathscr{A}_{\text{дов}})$')

plt.axis([-3.5, 6, 0, 1])
plt.xticks([0, 2.5], [0, r'$$\frac{\sqrt{n}(a_1 - a_0)}{\sigma}$$'])
plt.yticks([], [])

# blue_patch = mpatches.Patch(color='blue', alpha=0.2, label=r'$\alpha_{\mathrm{I}} / 2$')
# green_patch = mpatches.Patch(color='green', alpha=0.2, label=r'$\alpha_{\mathrm{I}} = \mathsf{P}_{H_1}(t \in A_{d}$')
# plt.legend(handles=[blue_patch, green_patch])

plt.grid()
plt.legend(loc='best').get_frame().set_linewidth(0.5)

plt.tight_layout(pad=0.1)

# plt.show()

# plt.ylim(0.4, 1)
# # for colors, see https://github.com/matplotlib/matplotlib/blob/master/lib/matplotlib/mpl-data/stylelib/ggplot.mplstyle
# plt.axhline(mean(res), label='Среднее', color='#348ABD')
# plt.ylabel('bar')
plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/h0_h1.pdf')
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.fill_between(x, y0, color='blue', alpha=0.2, where = (x > 1.5) & (x < 2))
plt.fill_between(x, y0, color='blue', alpha=0.2, where = (x > 2) & (x < 4))
plt.fill_between(x, y1, color='green', alpha=0.2, where = (x > -4) & (x < 1.5))
plt.plot(x, y0, label=r'$\mathrm{pdf}_t$ при верной $H_0$')
plt.plot(x, y1, label=r'$\mathrm{pdf}_t$ при верной $H_1$')
plt.plot([], [], color='blue', alpha=0.2, linewidth=10, label=r'$\alpha_{\mathrm{I}}$')
plt.plot([], [], color='green', alpha=0.2, linewidth=10, label=r'$\alpha_{\mathrm{II}} = \mathsf{P}_{H_1}(t \in \mathscr{A}_{\text{дов}})$')
plt.axis([-3.5, 6, 0, 1])
plt.xticks([0, 2.5], [0, r'$$\frac{\sqrt{n}(a_1 - a_0)}{\sigma}$$'])
plt.yticks([], [])
plt.grid()
plt.legend(loc='best').get_frame().set_linewidth(0.5)
plt.tight_layout(pad=0.1)
plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/h0_h1-opt.pdf')
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import scipy
from scipy.stats import binom

plt.plot(range(1, 11), [binom.cdf(x, 10, 0.5) for x in range(1, 11)], '.', label=r'$\mathrm{cdf}_{\mathrm{Bin}(10, 0.5)}$')
plt.hlines(0.9, 1, 10, color='red', label=r'$\alpha = 0.1$')
plt.fill_between([1, 10], 0.9, 1, alpha=0.1, color='red')
plt.xticks(range(1,11))
plot_margin = 0.05
x0, x1, y0, y1 = plt.axis()
plt.axis((x0 - plot_margin,
          x1 + plot_margin,
          y0 - plot_margin,
          y1 + plot_margin))
plt.grid()
plt.legend(loc='lower right').get_frame().set_linewidth(0.5)
plt.tight_layout(pad=0.1)
plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/mouse-bin-cdf.pdf')
plt.show()

# %%
xs = linspace(0, 1, 50)
ys = 1/sqrt(xs) + uniform.rvs(-1, 2, 50)
plt.plot(xs, ys, 'wo')
plt.plot(xs, 1/sqrt(xs), color='blue', )

# plt.axis([-3.5, 6, 0, 1])
# plt.xticks([0, 2.5], [0, r'$$\frac{\sqrt{n}(a_1 - a_0)}{\sigma}$$'])
plt.yticks([], [])
plt.xticks([0.75], [r'$x$'])

plt.grid()
# plt.legend(loc='best')
# plt.legend().get_frame().set_linewidth(0.5)

plt.xlabel(r'$\xi$')
plt.ylabel(r'$\eta$')

plt.tight_layout(pad=0.1)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/covar-hyperb.pdf')
plt.show()

# %%
xs = linspace(0, 1, 50)
ys = -xs + 1 + uniform.rvs(-0.5, 1, 50)
plt.plot(xs, ys, 'wo')
plt.plot(xs, -xs + 1, color='blue', )

# plt.axis([-3.5, 6, 0, 1])
# plt.xticks([0, 2.5], [0, r'$$\frac{\sqrt{n}(a_1 - a_0)}{\sigma}$$'])
plt.yticks([], [])
plt.xticks([0.75], [r'$x$'])

plt.grid()
plt.legend(loc='best')
# plt.legend().get_frame().set_linewidth(0.5)

plt.xlabel(r'$\xi$')
plt.ylabel(r'$\eta$')

plt.tight_layout(pad=0.1)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/covar-linear.pdf')
plt.show()

# %%
old_figsize = plt.rcParams['figure.figsize']
plt.rcParams['figure.figsize'] = (4.009962640099626, 4.009962640099626)

n_pts = 300
xs_m, ys_m = (norm.rvs(6, 0.5, size=n_pts), norm.rvs(2, 0.5, size=n_pts))
xs_f, ys_f = (norm.rvs(2, 0.5, size=n_pts), norm.rvs(6, 0.5, size=n_pts))
xs, ys = (concatenate((xs_m, xs_f)), concatenate((ys_m, ys_f)))
k, b, _, _, _ = linregress(xs, ys)
plt.plot(xs_m, ys_m, 'bD', alpha=0.2, label='Мужчины')
plt.plot(xs_f, ys_f, 'ro', alpha=0.2, label='Женщины')
xs_linreg = array((min(xs), max(xs)))
plt.plot(xs_linreg , k * xs_linreg  + b, color='green', label=r'$\rho=%s$' % round(k, 2))

ys_linreg = k * xs_linreg + b
# plt.axes().set_aspect('equal')

# plt.axis([-3.5, 6, 0, 1])
# plt.xticks([0, 2.5], [0, r'$$\frac{\sqrt{n}(a_1 - a_0)}{\sigma}$$'])
plt.yticks([], [])
plt.xticks([0], [0])

plt.grid()
plt.legend(loc='upper right')
plt.legend().get_frame().set_linewidth(0.5)

plt.xlabel(r'$\eta_1$' + ' (Рост)')
plt.ylabel(r'$\eta_2$' +' (Длина волос)')

plt.annotate(r'$$\begin{pmatrix}\mathsf{E}\{\eta_{1}\mid\xi=\mathrm{M}\}\\ \mathsf{E}\{\eta_{2}\mid\xi=\mathrm{M}\} \end{pmatrix} $$',
            xy=(6, 2), xycoords='data',
            xytext=(-30, 80), textcoords='offset points', fontsize=12,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=-.2"))

plt.annotate(r'$$\begin{pmatrix}\mathsf{E}\{\eta_{1}\mid\xi=\mathrm{F}\}\\ \mathsf{E}\{\eta_{2}\mid\xi=\mathrm{F}\} \end{pmatrix} $$',
            xy=(2, 6), xycoords='data',
            xytext=(-40, -120), textcoords='offset points', fontsize=12,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=-.2"))

plt.tight_layout(pad=0.1)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/part_corr-mf.pdf')
plt.show()
old_figsize = plt.rcParams['figure.figsize']

# %%
old_figsize = plt.rcParams['figure.figsize']
plt.rcParams['figure.figsize'] = (4.009962640099626, 4.009962640099626)

xs_m_centered = xs_m - 6
ys_m_centered = ys_m - 2
xs_f_centered = xs_f - 2
ys_f_centered = ys_f - 6
plt.plot(xs_m_centered, ys_m_centered, 'bD', alpha=0.2, label='Мужчины')
plt.plot(xs_f_centered, ys_f_centered, 'ro', alpha=0.2, label='Женщины')
plt.yticks([0], [0])
plt.xticks([0], [0])
plt.grid()
plt.axis([-2, 6, -2, 6])
plt.legend(loc='upper right')
plt.legend().get_frame().set_linewidth(0.5)

plt.xlabel(r'$\eta_1$' + ' (Рост)')
plt.ylabel(r'$\eta_2$' +' (Длина волос)')

plt.annotate(r'$$\begin{pmatrix}\eta_{1}-\hat{\eta}_{1}^{*}\\\eta_{2}-\hat{\eta}_{2}^{*}\end{pmatrix} $$',
            xy=(1, 1), xycoords='data',
            xytext=(40, 50), textcoords='offset points', fontsize=12,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.tight_layout(pad=0.1)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/part_corr_centered-mf.pdf')
plt.show()
plt.rcParams['figure.figsize'] = old_figsize

# %%
old_figsize = plt.rcParams['figure.figsize']
# plt.rcParams['figure.figsize'] = (5.346616853466169, 3.3043909402651086)
plt.rcParams['figure.figsize'] = (4.009962640099626, 2.4782932051988316) # 0.6

for m in [[0, 0], [4, 4]]:
    x, y = list(zip(*multivariate_normal.rvs(mean=m, cov=[[1, -0.7], [-0.7, 1]], size=300)));
    plt.plot(x, y, linestyle='None', marker='o', markeredgecolor='black', markerfacecolor='None', alpha=1);

plt.yticks([], [])
plt.xticks([], [])

# plt.grid()
# plt.legend().get_frame().set_linewidth(0.5)

plt.xlabel(r'$\eta_1$')
plt.ylabel(r'$\eta_2$')

plt.tight_layout(pad=0.1)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/part_corr-bivar_gauss.pdf')
plt.show()

plt.rcParams['figure.figsize'] = old_figsize

# %%
old_figsize = plt.rcParams['figure.figsize']
plt.rcParams['figure.figsize'] = (3.341635533416355, 2.0652443376656926)

x = 2
xs = linspace(0, 5)
ys = xs - x

plt.plot(xs, ys)

plt.ylim([0, 3])
plt.yticks([0], [0])
plt.xticks([x], [r'$x$'])
# plt.axis([x, 5, 0, 3])
plt.xlabel(r'$\beta_1$')
plt.ylabel(r'$\beta_2$')
plt.tight_layout(pad=0.5)
plt.savefig('/home/xio/Documents/СПбГУ/Теория вероятностей/ДЗ по УМО/fig/D.pdf')
plt.show()

plt.rcParams['figure.figsize'] = old_figsize

# %%
old_figsize = plt.rcParams['figure.figsize']
plt.rcParams['figure.figsize'] = (3.341635533416355, 2.0652443376656926)

# plt.axvline(x)
plt.axis([0, 5, 0, 3])

plt.fill_betweenx([0, 5], 2, 5, color='blue', alpha=0.2)


# x = 2
# xs = linspace(0, 5)
# ys = xs - x

# plt.plot(xs, ys)

plt.yticks([], [])
plt.xticks([x], [r'$x$'])

plt.xlabel(r'$\beta_1 + \beta_2$')
plt.ylabel(r'$\beta_1 - \beta_2$')
plt.tight_layout(pad=0.5)
plt.savefig('/home/xio/Documents/СПбГУ/Теория вероятностей/ДЗ по УМО/fig/G.pdf')
plt.show()

plt.rcParams['figure.figsize'] = old_figsize

# %%
old_figsize = plt.rcParams['figure.figsize']
# plt.rcParams['figure.figsize'] = (5.346616853466169, 3.3043909402651086)
# plt.rcParams['figure.figsize'] = (4.009962640099626, 2.4782932051988316) # 0.6
plt.rcParams['figure.figsize'] = (4.678289746782897, 2.8913420727319696) # 0.7


xs = linspace(-1, 1)
rho_S = xs
rho = 2 * sin(rho_S * pi/6)

plt.plot(xs, rho_S, color='blue', label=r'$\rho_S$')
plt.plot(xs, rho, color='red', label=r'$\rho = 2 \sin(\pi / 6 \rho_S)$')

# plt.axvline(x)
# plt.axis([0, 5, 0, 3])


# plt.yticks([], [])
# plt.xticks([x], [r'$x$'])

plt.xlabel(r'$\rho$')
plt.grid()
# plt.axis([-2, 6, -2, 6])
plt.legend(loc='lower right').get_frame().set_linewidth(0.5)

# plt.ylabel(r'$\beta_1 - \beta_2$')
plt.tight_layout(pad=0.5)
plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/rho-rho_S.pdf')
plt.show()

plt.rcParams['figure.figsize'] = old_figsize

# %%
old_figsize = plt.rcParams['figure.figsize']
# plt.rcParams['figure.figsize'] = (5.346616853466169, 3.3043909402651086)
# plt.rcParams['figure.figsize'] = (4.009962640099626, 2.4782932051988316) # 0.6
plt.rcParams['figure.figsize'] = (4.678289746782897, 2.8913420727319696) # 0.7


x, y = list(zip(*multivariate_normal.rvs(mean=[0, 0], cov=[[1, 0.5], [0.5, 1]], size=100)))
plt.plot(x, y, linestyle='None', marker='o', markeredgecolor='black', markerfacecolor='None', alpha=1)

# print(spearmanr(x,y))
init = (max(x), min(y))
outlier = (init[0], init[1])
while pearsonr(x + (outlier[0],), y + (outlier[1],))[0] > 0:
    outlier = (outlier[0] + 0.1, outlier[1] - 0.1)
# outlier = (init[0] + 10, init[1] - 10)
print(pearsonr(x + (outlier[0],), y + (outlier[1],)))

plt.plot(*outlier, linestyle='None', marker='o', markeredgecolor='red', markerfacecolor='None', alpha=1)

xs_linreg = array((min(x), outlier[0]))
k, b, _, _, _ = linregress(x, y)
plt.plot(xs_linreg , k * xs_linreg  + b, color='blue',
         label=r'w/o outlier ($\hat{\rho} = %s, \hat{\rho}_S = %s$)' % (round(pearsonr(x,y)[0], 2), round(spearmanr(x,y)[0], 2)))
k, b, _, _, _ = linregress(x + (outlier[0],), y + (outlier[1],))
plt.plot(xs_linreg , k * xs_linreg  + b, color='red',
         label=r'w outlier ($\hat{\rho} = 0, \hat{\rho}_S = %s$)' % round(spearmanr(x + (outlier[0],), y + (outlier[1],))[0], 2))

plt.yticks([], [])
plt.xticks([], [])

# plt.grid()
plt.legend(loc='lower left').get_frame().set_linewidth(0.5)

plt.xlabel(r'$\xi$')
plt.ylabel(r'$\eta$')

plt.tight_layout(pad=0.5)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/rho_outlier.pdf')
plt.show()
old_figsize = plt.rcParams['figure.figsize']
# Out:
# (-0.0038736910973277152, 0.96933234178204475)

# %%
old_figsize = plt.rcParams['figure.figsize']
# plt.rcParams['figure.figsize'] = (5.346616853466169, 3.3043909402651086)
# plt.rcParams['figure.figsize'] = (4.009962640099626, 2.4782932051988316) # 0.6
plt.rcParams['figure.figsize'] = (4.678289746782897, 2.8913420727319696) # 0.7


x, y = list(zip(*multivariate_normal.rvs(mean=[3, 3], cov=[[1, 0.9], [0.9, 1]], size=300)))
plt.plot(x, y, linestyle='None', marker='o', markeredgecolor='red', markerfacecolor='None', alpha=1,
         label=r'$\eta$ ($\hat{\rho} = %s, \hat{\rho}_S = %s$)' % (round(pearsonr(x,y)[0], 2), round(spearmanr(x,y)[0], 2)))

# xs_linreg = array((min(x), max(x)))
# k, b, _, _, _ = linregress(x, y)
# plt.plot(xs_linreg , k * xs_linreg  + b, color='red', linestyle='dashed')

# print(spearmanr(x,y))
# print(pearsonr(x,y))
# print(k)

y = [p**2 for p in y]
plt.plot(x, y, linestyle='None', marker='o', markeredgecolor='blue', markerfacecolor='None', alpha=1,
        label=r'$\eta^2$ ($\hat{\rho} = %s, \hat{\rho}_S = %s$)' % (round(pearsonr(x,y)[0], 2), round(spearmanr(x,y)[0], 2)))

# k, b, _, _, _ = linregress(x, y)
# plt.plot(xs_linreg , k * xs_linreg  + b, color='blue', linestyle='dashed')

# print(spearmanr(x,y))
# print(pearsonr(x,y))
# print(k)

# plt.yticks([], [])
# plt.xticks([], [])

plt.grid()
plt.legend(loc='upper left').get_frame().set_linewidth(0.5)

plt.xlabel(r'$\xi$')
# plt.ylabel(r'$\eta^2$')

plt.tight_layout(pad=0.5)

plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/rho_monotone.pdf')
plt.show()
old_figsize = plt.rcParams['figure.figsize']

# %%
x = array([4.0,2.5,3.2,5.8,7.4,4.4,8.3,8.5])
y = array([2.1,4.0,1.5,6.3,5.0,5.8,8.1,7.1])
 
# fit a curve to the data using a least squares 1st order polynomial fit
z = polyfit(x,y,1)
p = poly1d(z)
fit = p(x)

# get the coordinates for the fit curve
c_y = [min(fit),max(fit)]
c_x = [min(x),max(x)]
 
# predict y values of origional data using the fit
p_y = fit

# calculate the y-error (residuals)
y_err = y - p_y
 
# create series of new test x-values to predict for
p_x = arange(min(x),max(x)+1,1)
 
# now calculate confidence intervals for new test x-series
mean_x = mean(x)         # mean of x
n = len(x)              # number of samples in origional fit
t = 2.31                # appropriate t value (where n=9, two tailed 95%)
s_err = sum(power(y_err,2))   # sum of the squares of the residuals
 
confs = t * sqrt((s_err/(n-2))*(1.0/n + (power((p_x-mean_x),2)/
            ((sum(power(x,2)))-n*(power(mean_x,2))))))
 
# now predict y based on test x-values
p_y = z[0]*p_x+z[0]
 
# get lower and upper confidence limits based on predicted y and confidence intervals
lower = p_y - abs(confs)
upper = p_y + abs(confs)
 
# set-up the plot
plt.axes().set_aspect('equal')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear regression and confidence limits')
 
# plot sample data
plt.plot(x,y,'bo',label='Sample observations')
 
# plot line of best fit
plt.plot(c_x,c_y,'r-',label='Regression line')
 
# plot confidence limits
plt.plot(p_x,lower,'b--',label='Lower confidence limit (95%)')
plt.plot(p_x,upper,'b--',label='Upper confidence limit (95%)')
 
# set coordinate limits
plt.xlim(0,11)
plt.ylim(0,11)
 
# configure legend
plt.legend(loc=0)
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=10)
 
# show the plot
plt.show()

# %%
old_figsize = plt.rcParams['figure.figsize']
# plt.rcParams['figure.figsize'] = (5.346616853466169, 3.3043909402651086)
# plt.rcParams['figure.figsize'] = (4.009962640099626, 2.4782932051988316) # 0.6
plt.rcParams['figure.figsize'] = (4.678289746782897, 2.8913420727319696) # 0.7


xs = linspace(-1, 1)
tau = xs
rho = sin(tau * pi/2)

plt.plot(xs, tau, color='blue', label=r'$\tau$')
plt.plot(xs, rho, color='red', label=r'$\rho = \sin(\pi / 2 \tau)$')

# plt.axvline(x)
# plt.axis([0, 5, 0, 3])


# plt.yticks([], [])
# plt.xticks([x], [r'$x$'])

plt.xlabel(r'$\tau$')
plt.grid()
# plt.axis([-2, 6, -2, 6])
plt.legend(loc='lower right').get_frame().set_linewidth(0.5)

# plt.ylabel(r'$\beta_1 - \beta_2$')
plt.tight_layout(pad=0.5)
plt.savefig('/home/xio/Documents/СПбГУ/Конспекты лекций (CVS)/Statistics/6/fig/rho-tau.pdf')
plt.show()

plt.rcParams['figure.figsize'] = old_figsize
